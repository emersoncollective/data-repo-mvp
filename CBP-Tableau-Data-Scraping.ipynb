# %% [markdown]
# # CBP Encounters Scraping

# %% [markdown]
# ## Purpose

# %% [markdown]
# This notebook provides functionality to "scrape" or extract all data from the first Tableau dashboard on the [CBP Southwest Land Border Encounters](https://www.cbp.gov/newsroom/stats/southwest-land-border-encounters) page. CBP does not provide this data in a spreadsheet format nor does it enable download of the data through the embedded Tableau chart. Therefore this code was developed to pull down all the data included every data point that exists with every possible combination of filters.
#
# **Please note:** When using the data output by this notebook for analysis or exploration that you must filter the data based on the filter columns [Citizenship Grouping,	Component,	Demographic,	Title of Authority]. These columns coorespond to the filters.

# %% [markdown]
# ## Approach

# %% [markdown]
# We use a the python programming language along with some python libraries that simplify the process of extracting data from the dashboard.
#
#  The [TableauScraper](https://github.com/bertrandmartel/tableau-scraping) library (an open source project)  provides the primary functionality for extracting data from Tableau.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd drive/Shareddrives/Data\ Products\ Team/Products/Immigration\ Data\ Hub/DataRepo/
# Out:
# /content/drive/Shareddrives/Data Products Team/Products/Immigration Data Hub/DataRepo

# %% [markdown]
# ## The Code !

# %%
# !pip install TableauScraper
# !pip install pandas
# Out:
# Requirement already satisfied: TableauScraper in /usr/local/lib/python3.7/dist-packages (0.1.28)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from TableauScraper) (1.1.5)
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.7/dist-packages (from TableauScraper) (2.23.0)
# Requirement already satisfied: beautifulsoup4>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from TableauScraper) (4.6.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->TableauScraper) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->TableauScraper) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->TableauScraper) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->TableauScraper) (1.24.3)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->TableauScraper) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->TableauScraper) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->TableauScraper) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->TableauScraper) (1.15.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import helper python libraries
from tableauscraper import TableauScraper as TS
import itertools
import logging
import time
import pprint
import pandas as pd

pp = pprint.PrettyPrinter(indent=4)
import logging.config

from cbp_tableau_scraping import find_filters_worksheet, unpack_filter_information, get_dashboard_data

logging.config.dictConfig(
    {
        "version": 1,
        "disable_existing_loggers": True,
    }
)

# %% [markdown]
# ### First We Grab the CBP Tableau Data

# %% [markdown]
# The cbp url see [link](todo) on how to find the url
#
# TODO --> Maybe se if there is an automated way to grab this

# %%
dashboard1_url = (
    "https://publicstats.cbp.gov/t/PublicFacing/views/"
    "CBPSBOEnforcementActionsDashboardsAUGFY21/"
    "SBOEncounters8076?:isGuestRedirectFromVizportal=y&:embed=y"
)

dashboard2_url =  (
    "https://publicstats.cbp.gov/t/PublicFacing/views/"
    "CBPSBOEnforcementActionsDashboardsAUGFY21/"
    "SBObyMonthDemo8076?:isGuestRedirectFromVizportal=y&:embed=y"
)

# %% [markdown]
# Here we activate (instantiate is the technical term) the TableauScraper library and then load data from the dashboard url.

# %% [markdown]
# **Dashboard to load**

# %%
current_dashboard = dashboard2_url

# %%
# Create a tableau scraper object
ts = TS()

# We then pass the url to that object and it grabs data from the CBP dashboard
ts.loads(dashboard2_url)

# %% [markdown]
# The tableau dashboard has the filters linked to a specific visualization. On the CBP page we have a line chart, table and a bar chart in the first embedded dashboard. We want to extract the table or line data as they contain the same information. We need to find the visualization that has the filters that will update all three charts.
#
# TODO - Explain more about filters, worksheets and workboks ...

# %%
??find_filters_worksheet

# %%
filters_ws, wb_names = find_filters_worksheet(ts)
# Out:
# Filters Presesnt on worksheet name --> All MoM Change Podium
# [   {   'column': 'Citizenship Grouping',
#         'globalFieldName': '[federated.1xhccc00nlacbx14ajs101w1uee1].[none:Citizenship '
#                            'Grouping:nk]',
#         'ordinal': 0,
#         'selection': [   'El Salvador',
#                          'Guatemala',
#                          'Honduras',
#                          'Mexico',
#                          'Other',
#                          'all'],
#         'selectionAlt': [   {   'columnFullNames': ['[Citizenship Grouping]'],
#                                 'domainTables': [   {   'isSelected': True,
#                                                         'label': 'El '
#                                                                  'Salvador'}],
#                                 'fn': '[federated.1xhccc00nlacbx14ajs101w1uee1].[none:Citizenship '
#                                       'Grouping:nk]'}],
#         'values': ['El Salvador', 'Guatemala', 'Honduras', 'Mexico', 'Other']},
#     {   'column': 'Demographic',
#         'globalFieldName': '[federated.1xhccc00nlacbx14ajs101w1uee1].[none:Demographic:nk]',
#         'ordinal': 0,
#         'selection': [   'Accompanied Minors',
#                          'FMUA',
#                          'Single Adults',
#                          'UC / Single Minors',
#                          'all'],
#         'selectionAlt': [   {   'columnFullNames': ['[Demographic]'],
#                                 'domainTables': [   {   'isSelected': True,
#                                                         'label': 'AM'}],
#                                 'fn': '[federated.1xhccc00nlacbx14ajs101w1uee1].[none:Demographic:nk]'}],
#         'values': [   'Accompanied Minors',
#                       'FMUA',
#                       'Single Adults',
#                       'UC / Single Minors']},
#     {   'column': 'Title of Authority',
#         'globalFieldName': '[federated.1xhccc00nlacbx14ajs101w1uee1].[none:Title '
#                            'of Authority:nk]',
#         'ordinal': 0,
#         'selection': ['Title 8', 'Title 42', 'all'],
#         'selectionAlt': [   {   'columnFullNames': ['[Title of Authority]'],
#                                 'domainTables': [   {   'isSelected': True,
#                                                         'label': 'Title 8'}],
#                                 'fn': '[federated.1xhccc00nlacbx14ajs101w1uee1].[none:Title '
#                                       'of Authority:nk]'}],
#         'values': ['Title 8', 'Title 42']}]
# no filters Demo FYTD by Month (2)
# no filters OFO MoM Change
# no filters Reset SBO by Month
# no filters USBP MoM Change

# %% [markdown]
# Above we can see which worksheet has the filters, if we are using the first url the filters are on the `SBO Line Graph` worksheet, if using the second url the filtes are on the `All MoM Change Podium` worksheet.
#
#  The `filters_ws` holds the value for which worksheet has the filters.

# %%
print(filters_ws)
# Out:
# All MoM Change Podium

# %%
data_element_target = 'Demo FYTD by Month (2)'

# %%
filters_ws, wb_names = find_filters_worksheet(ts)
# Out:
# Filters Presesnt on worksheet name --> All MoM Change Podium
# [   {   'column': 'Citizenship Grouping',
#         'globalFieldName': '[federated.1xhccc00nlacbx14ajs101w1uee1].[none:Citizenship '
#                            'Grouping:nk]',
#         'ordinal': 0,
#         'selection': [   'El Salvador',
#                          'Guatemala',
#                          'Honduras',
#                          'Mexico',
#                          'Other',
#                          'all'],
#         'selectionAlt': [   {   'columnFullNames': ['[Citizenship Grouping]'],
#                                 'domainTables': [   {   'isSelected': True,
#                                                         'label': 'El '
#                                                                  'Salvador'}],
#                                 'fn': '[federated.1xhccc00nlacbx14ajs101w1uee1].[none:Citizenship '
#                                       'Grouping:nk]'}],
#         'values': ['El Salvador', 'Guatemala', 'Honduras', 'Mexico', 'Other']},
#     {   'column': 'Demographic',
#         'globalFieldName': '[federated.1xhccc00nlacbx14ajs101w1uee1].[none:Demographic:nk]',
#         'ordinal': 0,
#         'selection': [   'Accompanied Minors',
#                          'FMUA',
#                          'Single Adults',
#                          'UC / Single Minors',
#                          'all'],
#         'selectionAlt': [   {   'columnFullNames': ['[Demographic]'],
#                                 'domainTables': [   {   'isSelected': True,
#                                                         'label': 'AM'}],
#                                 'fn': '[federated.1xhccc00nlacbx14ajs101w1uee1].[none:Demographic:nk]'}],
#         'values': [   'Accompanied Minors',
#                       'FMUA',
#                       'Single Adults',
#                       'UC / Single Minors']},
#     {   'column': 'Title of Authority',
#         'globalFieldName': '[federated.1xhccc00nlacbx14ajs101w1uee1].[none:Title '
#                            'of Authority:nk]',
#         'ordinal': 0,
#         'selection': ['Title 8', 'Title 42', 'all'],
#         'selectionAlt': [   {   'columnFullNames': ['[Title of Authority]'],
#                                 'domainTables': [   {   'isSelected': True,
#                                                         'label': 'Title 8'}],
#                                 'fn': '[federated.1xhccc00nlacbx14ajs101w1uee1].[none:Title '
#                                       'of Authority:nk]'}],
#         'values': ['Title 8', 'Title 42']}]
# no filters Demo FYTD by Month (2)
# no filters OFO MoM Change
# no filters Reset SBO by Month
# no filters USBP MoM Change

# %% [markdown]
# ### Next, we build out all possible combinations of filters

# %%
??unpack_filter_information

# %%
filter_data = unpack_filter_information(ts, filters_ws, skip_filters = ['Demographic'])
# Out:
# {   'Citizenship Grouping': [   'El Salvador',
#                                 'Guatemala',
#                                 'Honduras',
#                                 'Mexico',
#                                 'Other'],
#     'Demographic': [   'Accompanied Minors',
#                        'FMUA',
#                        'Single Adults',
#                        'UC / Single Minors'],
#     'Title of Authority': ['Title 8', 'Title 42']}
# Fiscal year not present

# %%
# See the various combinations
pp.pprint(filter_data['filter_combinations'])
# Out:
# [   (None, None, None),
#     (None, None, 'Title 8'),
#     (None, None, 'Title 42'),
#     (None, 'Accompanied Minors', None),
#     (None, 'Accompanied Minors', 'Title 8'),
#     (None, 'Accompanied Minors', 'Title 42'),
#     (None, 'FMUA', None),
#     (None, 'FMUA', 'Title 8'),
#     (None, 'FMUA', 'Title 42'),
#     (None, 'Single Adults', None),
#     (None, 'Single Adults', 'Title 8'),
#     (None, 'Single Adults', 'Title 42'),
#     (None, 'UC / Single Minors', None),
#     (None, 'UC / Single Minors', 'Title 8'),
#     (None, 'UC / Single Minors', 'Title 42'),
#     ('El Salvador', None, None),
#     ('El Salvador', None, 'Title 8'),
#     ('El Salvador', None, 'Title 42'),
#     ('El Salvador', 'Accompanied Minors', None),
#     ('El Salvador', 'Accompanied Minors', 'Title 8'),
#     ('El Salvador', 'Accompanied Minors', 'Title 42'),
#     ('El Salvador', 'FMUA', None),
#     ('El Salvador', 'FMUA', 'Title 8'),
#     ('El Salvador', 'FMUA', 'Title 42'),
#     ('El Salvador', 'Single Adults', None),
#     ('El Salvador', 'Single Adults', 'Title 8'),
#     ('El Salvador', 'Single Adults', 'Title 42'),
#     ('El Salvador', 'UC / Single Minors', None),
#     ('El Salvador', 'UC / Single Minors', 'Title 8'),
#     ('El Salvador', 'UC / Single Minors', 'Title 42'),
#     ('Guatemala', None, None),
#     ('Guatemala', None, 'Title 8'),
#     ('Guatemala', None, 'Title 42'),
#     ('Guatemala', 'Accompanied Minors', None),
#     ('Guatemala', 'Accompanied Minors', 'Title 8'),
#     ('Guatemala', 'Accompanied Minors', 'Title 42'),
#     ('Guatemala', 'FMUA', None),
#     ('Guatemala', 'FMUA', 'Title 8'),
#     ('Guatemala', 'FMUA', 'Title 42'),
#     ('Guatemala', 'Single Adults', None),
#     ('Guatemala', 'Single Adults', 'Title 8'),
#     ('Guatemala', 'Single Adults', 'Title 42'),
#     ('Guatemala', 'UC / Single Minors', None),
#     ('Guatemala', 'UC / Single Minors', 'Title 8'),
#     ('Guatemala', 'UC / Single Minors', 'Title 42'),
#     ('Honduras', None, None),
#     ('Honduras', None, 'Title 8'),
#     ('Honduras', None, 'Title 42'),
#     ('Honduras', 'Accompanied Minors', None),
#     ('Honduras', 'Accompanied Minors', 'Title 8'),
#     ('Honduras', 'Accompanied Minors', 'Title 42'),
#     ('Honduras', 'FMUA', None),
#     ('Honduras', 'FMUA', 'Title 8'),
#     ('Honduras', 'FMUA', 'Title 42'),
#     ('Honduras', 'Single Adults', None),
#     ('Honduras', 'Single Adults', 'Title 8'),
#     ('Honduras', 'Single Adults', 'Title 42'),
#     ('Honduras', 'UC / Single Minors', None),
#     ('Honduras', 'UC / Single Minors', 'Title 8'),
#     ('Honduras', 'UC / Single Minors', 'Title 42'),
#     ('Mexico', None, None),
#     ('Mexico', None, 'Title 8'),
#     ('Mexico', None, 'Title 42'),
#     ('Mexico', 'Accompanied Minors', None),
#     ('Mexico', 'Accompanied Minors', 'Title 8'),
#     ('Mexico', 'Accompanied Minors', 'Title 42'),
#     ('Mexico', 'FMUA', None),
#     ('Mexico', 'FMUA', 'Title 8'),
#     ('Mexico', 'FMUA', 'Title 42'),
#     ('Mexico', 'Single Adults', None),
#     ('Mexico', 'Single Adults', 'Title 8'),
#     ('Mexico', 'Single Adults', 'Title 42'),
#     ('Mexico', 'UC / Single Minors', None),
#     ('Mexico', 'UC / Single Minors', 'Title 8'),
#     ('Mexico', 'UC / Single Minors', 'Title 42'),
#     ('Other', None, None),
#     ('Other', None, 'Title 8'),
#     ('Other', None, 'Title 42'),
#     ('Other', 'Accompanied Minors', None),
#     ('Other', 'Accompanied Minors', 'Title 8'),
#     ('Other', 'Accompanied Minors', 'Title 42'),
#     ('Other', 'FMUA', None),
#     ('Other', 'FMUA', 'Title 8'),
#     ('Other', 'FMUA', 'Title 42'),
#     ('Other', 'Single Adults', None),
#     ('Other', 'Single Adults', 'Title 8'),
#     ('Other', 'Single Adults', 'Title 42'),
#     ('Other', 'UC / Single Minors', None),
#     ('Other', 'UC / Single Minors', 'Title 8'),
#     ('Other', 'UC / Single Minors', 'Title 42')]

# %% [markdown]
# ### Now lets pull down the data

# %% [markdown]
# **Data Extraction Function**
#
# We wil create a function to pull down the data and paramaterize some of the arguments

# %% [markdown]
# This may take about 20 minutes

# %%
dataset, failed_combination = get_dashboard_data(
    current_dashboard, filter_data['filter_columns'], filter_data['filter_combinations'], filters_ws, data_element_target
)
# Out:
# Attempting Fitler Combination (None, None, None)
# Attempting Fitler Combination (None, None, 'Title 8')
# Attempting Fitler Combination (None, None, 'Title 42')
# Attempting Fitler Combination (None, 'Accompanied Minors', None)
# Attempting Fitler Combination (None, 'Accompanied Minors', 'Title 8')
# Attempting Fitler Combination (None, 'Accompanied Minors', 'Title 42')
# Attempting Fitler Combination (None, 'FMUA', None)
# Attempting Fitler Combination (None, 'FMUA', 'Title 8')
# Attempting Fitler Combination (None, 'FMUA', 'Title 42')
# Attempting Fitler Combination (None, 'Single Adults', None)
# Attempting Fitler Combination (None, 'Single Adults', 'Title 8')
# Attempting Fitler Combination (None, 'Single Adults', 'Title 42')
# Attempting Fitler Combination (None, 'UC / Single Minors', None)
# Attempting Fitler Combination (None, 'UC / Single Minors', 'Title 8')
# Attempting Fitler Combination (None, 'UC / Single Minors', 'Title 42')
# Attempting Fitler Combination ('El Salvador', None, None)
# Attempting Fitler Combination ('El Salvador', None, 'Title 8')
# Attempting Fitler Combination ('El Salvador', None, 'Title 42')
# Attempting Fitler Combination ('El Salvador', 'Accompanied Minors', None)
# Attempting Fitler Combination ('El Salvador', 'Accompanied Minors', 'Title 8')
# Attempting Fitler Combination ('El Salvador', 'Accompanied Minors', 'Title 42')
# Attempting Fitler Combination ('El Salvador', 'FMUA', None)
# Attempting Fitler Combination ('El Salvador', 'FMUA', 'Title 8')
# Attempting Fitler Combination ('El Salvador', 'FMUA', 'Title 42')
# Attempting Fitler Combination ('El Salvador', 'Single Adults', None)
# Attempting Fitler Combination ('El Salvador', 'Single Adults', 'Title 8')
# Attempting Fitler Combination ('El Salvador', 'Single Adults', 'Title 42')
# Attempting Fitler Combination ('El Salvador', 'UC / Single Minors', None)
# Attempting Fitler Combination ('El Salvador', 'UC / Single Minors', 'Title 8')
# Attempting Fitler Combination ('El Salvador', 'UC / Single Minors', 'Title 42')
# Attempting Fitler Combination ('Guatemala', None, None)
# Attempting Fitler Combination ('Guatemala', None, 'Title 8')
# Attempting Fitler Combination ('Guatemala', None, 'Title 42')
# Attempting Fitler Combination ('Guatemala', 'Accompanied Minors', None)
# Attempting Fitler Combination ('Guatemala', 'Accompanied Minors', 'Title 8')
# Attempting Fitler Combination ('Guatemala', 'Accompanied Minors', 'Title 42')
# Attempting Fitler Combination ('Guatemala', 'FMUA', None)
# Attempting Fitler Combination ('Guatemala', 'FMUA', 'Title 8')
# Attempting Fitler Combination ('Guatemala', 'FMUA', 'Title 42')
# Attempting Fitler Combination ('Guatemala', 'Single Adults', None)
# Attempting Fitler Combination ('Guatemala', 'Single Adults', 'Title 8')
# Attempting Fitler Combination ('Guatemala', 'Single Adults', 'Title 42')
# Attempting Fitler Combination ('Guatemala', 'UC / Single Minors', None)
# Attempting Fitler Combination ('Guatemala', 'UC / Single Minors', 'Title 8')
# Attempting Fitler Combination ('Guatemala', 'UC / Single Minors', 'Title 42')
# Attempting Fitler Combination ('Honduras', None, None)
# Attempting Fitler Combination ('Honduras', None, 'Title 8')
# Attempting Fitler Combination ('Honduras', None, 'Title 42')
# Attempting Fitler Combination ('Honduras', 'Accompanied Minors', None)
# Attempting Fitler Combination ('Honduras', 'Accompanied Minors', 'Title 8')
# Attempting Fitler Combination ('Honduras', 'Accompanied Minors', 'Title 42')
# Attempting Fitler Combination ('Honduras', 'FMUA', None)
# Attempting Fitler Combination ('Honduras', 'FMUA', 'Title 8')
# Attempting Fitler Combination ('Honduras', 'FMUA', 'Title 42')
# Attempting Fitler Combination ('Honduras', 'Single Adults', None)
# Attempting Fitler Combination ('Honduras', 'Single Adults', 'Title 8')
# Attempting Fitler Combination ('Honduras', 'Single Adults', 'Title 42')
# Attempting Fitler Combination ('Honduras', 'UC / Single Minors', None)
# Attempting Fitler Combination ('Honduras', 'UC / Single Minors', 'Title 8')
# Attempting Fitler Combination ('Honduras', 'UC / Single Minors', 'Title 42')
# Attempting Fitler Combination ('Mexico', None, None)
# Attempting Fitler Combination ('Mexico', None, 'Title 8')
# Attempting Fitler Combination ('Mexico', None, 'Title 42')
# Attempting Fitler Combination ('Mexico', 'Accompanied Minors', None)
# Attempting Fitler Combination ('Mexico', 'Accompanied Minors', 'Title 8')
# Attempting Fitler Combination ('Mexico', 'Accompanied Minors', 'Title 42')
# Attempting Fitler Combination ('Mexico', 'FMUA', None)
# Attempting Fitler Combination ('Mexico', 'FMUA', 'Title 8')
# Attempting Fitler Combination ('Mexico', 'FMUA', 'Title 42')
# Attempting Fitler Combination ('Mexico', 'Single Adults', None)
# Attempting Fitler Combination ('Mexico', 'Single Adults', 'Title 8')
# Attempting Fitler Combination ('Mexico', 'Single Adults', 'Title 42')
# Attempting Fitler Combination ('Mexico', 'UC / Single Minors', None)
# Attempting Fitler Combination ('Mexico', 'UC / Single Minors', 'Title 8')
# Attempting Fitler Combination ('Mexico', 'UC / Single Minors', 'Title 42')
# Attempting Fitler Combination ('Other', None, None)
# Attempting Fitler Combination ('Other', None, 'Title 8')
# Attempting Fitler Combination ('Other', None, 'Title 42')
# Attempting Fitler Combination ('Other', 'Accompanied Minors', None)
# Attempting Fitler Combination ('Other', 'Accompanied Minors', 'Title 8')
# Attempting Fitler Combination ('Other', 'Accompanied Minors', 'Title 42')
# Attempting Fitler Combination ('Other', 'FMUA', None)
# Attempting Fitler Combination ('Other', 'FMUA', 'Title 8')
# Attempting Fitler Combination ('Other', 'FMUA', 'Title 42')
# Attempting Fitler Combination ('Other', 'Single Adults', None)
# Attempting Fitler Combination ('Other', 'Single Adults', 'Title 8')
# Attempting Fitler Combination ('Other', 'Single Adults', 'Title 42')
# Attempting Fitler Combination ('Other', 'UC / Single Minors', None)
# Attempting Fitler Combination ('Other', 'UC / Single Minors', 'Title 8')
# Attempting Fitler Combination ('Other', 'UC / Single Minors', 'Title 42')

# %% [markdown]
# **Check if anything failed**

# %%
print(len(failed_combination))
print(failed_combination)
# Out:
# 0
# []

# %% [markdown]
# ## Review Data

# %%
dataset.shape
# Out:
# (5376, 11)

# %%
dataset
# Out:
#                Component-value  ... Title of Authority
# 0   Office of Field Operations  ...                all
# 1   Office of Field Operations  ...                all
# 2   Office of Field Operations  ...                all
# 3   Office of Field Operations  ...                all
# 4   Office of Field Operations  ...                all
# ..                         ...  ...                ...
# 8           U.S. Border Patrol  ...           Title 42
# 9           U.S. Border Patrol  ...           Title 42
# 10                       %all%  ...           Title 42
# 11                       %all%  ...           Title 42
# 12                       %all%  ...           Title 42
#
# [5376 rows x 11 columns]

# %%
dataset[(dataset['Citizenship Grouping'] == 'El Salvador')
      & (dataset['Demographic'] == 'all')
      & (dataset['Title of Authority'] == 'all')
      & (dataset['Component-value'] == 'Office of Field Operations')
]
# Out:
#                Component-value  ... Title of Authority
# 0   Office of Field Operations  ...                all
# 1   Office of Field Operations  ...                all
# 2   Office of Field Operations  ...                all
# 3   Office of Field Operations  ...                all
# 4   Office of Field Operations  ...                all
# 5   Office of Field Operations  ...                all
# 6   Office of Field Operations  ...                all
# 7   Office of Field Operations  ...                all
# 8   Office of Field Operations  ...                all
# 9   Office of Field Operations  ...                all
# 10  Office of Field Operations  ...                all
# 11  Office of Field Operations  ...                all
# 12  Office of Field Operations  ...                all
# 13  Office of Field Operations  ...                all
# 14  Office of Field Operations  ...                all
# 15  Office of Field Operations  ...                all
# 16  Office of Field Operations  ...                all
# 17  Office of Field Operations  ...                all
# 18  Office of Field Operations  ...                all
# 19  Office of Field Operations  ...                all
# 20  Office of Field Operations  ...                all
# 21  Office of Field Operations  ...                all
# 22  Office of Field Operations  ...                all
# 23  Office of Field Operations  ...                all
# 24  Office of Field Operations  ...                all
# 25  Office of Field Operations  ...                all
# 26  Office of Field Operations  ...                all
# 27  Office of Field Operations  ...                all
# 28  Office of Field Operations  ...                all
# 29  Office of Field Operations  ...                all
# 30  Office of Field Operations  ...                all
# 31  Office of Field Operations  ...                all
# 32  Office of Field Operations  ...                all
# 33  Office of Field Operations  ...                all
# 34  Office of Field Operations  ...                all
# 35  Office of Field Operations  ...                all
# 36  Office of Field Operations  ...                all
# 37  Office of Field Operations  ...                all
# 38  Office of Field Operations  ...                all
# 39  Office of Field Operations  ...                all
# 40  Office of Field Operations  ...                all
# 41  Office of Field Operations  ...                all
# 42  Office of Field Operations  ...                all
# 43  Office of Field Operations  ...                all
# 44  Office of Field Operations  ...                all
# 45  Office of Field Operations  ...                all
# 46  Office of Field Operations  ...                all
# 47  Office of Field Operations  ...                all
# 48  Office of Field Operations  ...                all
# 49  Office of Field Operations  ...                all
# 50  Office of Field Operations  ...                all
# 51  Office of Field Operations  ...                all
# 52  Office of Field Operations  ...                all
# 53  Office of Field Operations  ...                all
# 54  Office of Field Operations  ...                all
# 55  Office of Field Operations  ...                all
# 56  Office of Field Operations  ...                all
#
# [57 rows x 11 columns]

# %% [markdown]
# # End
